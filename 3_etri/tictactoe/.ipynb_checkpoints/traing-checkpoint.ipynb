# %%
import os
import shutil
import numpy as np
import tensorflow as tf

# %%
def inference(x_ph):
    hidden1 = tf.layers.dense(x_ph, 32, activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, 32, activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, 3)
    return logits

# %%
np.random.seed(1)

mat = np.loadtxt("data/tictactoe.csv", skiprows=1, delimiter=",")
ind_train = np.random.choice(5890, 4000, replace=False)
ind_test = np.array([i for i in range(5890) if i not in ind_train])

# %%
x_train = mat[ind_train, :-1]
x_test = mat[ind_test, :-1]
y_all = np.zeros([len(mat), 3])
for i, j in enumerate(mat[:, -1]):
    if j == 1:
        # x win
        y_all[i][0] = 1.
    elif j == -1:
        # o win
        y_all[i][1] = 1.
    else:
        # draw
        y_all[i][2] = 1.
y_train = y_all[ind_train]
y_test = y_all[ind_test]

# %%
with tf.Graph().as_default() as g:
    tf.set_random_seed(0)
    x_ph = tf.placeholder(tf.float32, [None, 9])
    y_ph = tf.placeholder(tf.float32, [None, 3])
    logits = inference(x_ph)
    y = tf.nn.softmax(logits)
    cross_entropy = tf.losses.softmax_cross_entropy(onehot_labels=y_ph, logits=logits, label_smoothing=1e-5)
    correct_prediction = tf.equal(tf.argmax(y, 1), tf.argmax(y_ph, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    train_op = tf.train.AdamOptimizer(learning_rate=0.01).minimize(cross_entropy)
    init_op = tf.global_variables_initializer()
    saver = tf.train.Saver()
    with tf.Session() as sess:
        sess.run(init_op)
        for i in range(10000):
            ind = np.random.choice(len(y_train), 1000)
            sess.run(train_op, feed_dict={x_ph: x_train[ind], y_ph: y_train[ind]})
            if i % 100 == 0:
                train_loss = sess.run(cross_entropy, feed_dict={x_ph: x_train, y_ph: y_train})
                train_accuracy, y_pred = sess.run([accuracy, y], feed_dict={x_ph: x_train, y_ph: y_train})
                test_accuracy = sess.run(accuracy, feed_dict={x_ph: x_test, y_ph: y_test})
                print(
                    "Iteration: {0} Loss: {1} Train Accuracy: {2} Test Accuracy{3}".format(
                        i, train_loss, train_accuracy, test_accuracy
                    )
                )
        if not os.path.isdir("checkpoints"):
            os.mkdir("checkpoints")
        saver.save(sess, "checkpoints/tictactoe")
        # Remove old model
        if os.path.exists("model"):
            shutil.rmtree("model")
        # Save model for deployment on ML Engine
        input_key = tf.placeholder(tf.int64, [None, ], name="key")
        output_key = tf.identity(input_key)
        input_signatures = {
            "key": tf.saved_model.utils.build_tensor_info(input_key),
            "x": tf.saved_model.utils.build_tensor_info(x_ph)
        }
        output_signatures = {
            "key": tf.saved_model.utils.build_tensor_info(output_key),
            "y": tf.saved_model.utils.build_tensor_info(y)
        }
        predict_signature_def = tf.saved_model.signature_def_utils.build_signature_def(
            input_signatures,
            output_signatures,
            tf.saved_model.signature_constants.PREDICT_METHOD_NAME
        )
        builder = tf.saved_model.builder.SavedModelBuilder(os.path.join("model"))
        builder.add_meta_graph_and_variables(
            sess,
            [tf.saved_model.tag_constants.SERVING],
            signature_def_map={
                tf.saved_model.signature_constants.DEFAULT_SERVING_SIGNATURE_DEF_KEY: predict_signature_def
            },
            assets_collection=tf.get_collection(tf.GraphKeys.ASSET_FILEPATHS)
        )
        builder.save()
# Out:
# Iteration: 0 Loss: 1.07309949398 Train Accuracy: 0.435750007629 Test Accuracy0.436507940292
# Iteration: 100 Loss: 0.279195040464 Train Accuracy: 0.895500004292 Test Accuracy0.873015880585
# Iteration: 200 Loss: 0.10808788985 Train Accuracy: 0.964999973774 Test Accuracy0.933862447739
# Iteration: 300 Loss: 0.0665503665805 Train Accuracy: 0.981999993324 Test Accuracy0.941269814968
# Iteration: 400 Loss: 0.0435070618987 Train Accuracy: 0.990499973297 Test Accuracy0.940740764141
# Iteration: 500 Loss: 0.031363401562 Train Accuracy: 0.992999970913 Test Accuracy0.940740764141
# Iteration: 600 Loss: 0.0179994627833 Train Accuracy: 0.99849998951 Test Accuracy0.943915367126
# Iteration: 700 Loss: 0.0133897000924 Train Accuracy: 0.999000012875 Test Accuracy0.937566161156
# Iteration: 800 Loss: 0.00975805241615 Train Accuracy: 0.99975001812 Test Accuracy0.939682543278
# Iteration: 900 Loss: 0.00659464485943 Train Accuracy: 0.99975001812 Test Accuracy0.938624322414
# Iteration: 1000 Loss: 0.00470126932487 Train Accuracy: 1.0 Test Accuracy0.937566161156
# Iteration: 1100 Loss: 0.00356348161586 Train Accuracy: 1.0 Test Accuracy0.938095211983
# Iteration: 1200 Loss: 0.00293240137398 Train Accuracy: 1.0 Test Accuracy0.938095211983
# Iteration: 1300 Loss: 0.00232222885825 Train Accuracy: 1.0 Test Accuracy0.936507940292
# Iteration: 1400 Loss: 0.00193158455659 Train Accuracy: 1.0 Test Accuracy0.935978829861
# Iteration: 1500 Loss: 0.00166253466159 Train Accuracy: 1.0 Test Accuracy0.935978829861
# Iteration: 1600 Loss: 0.00143489509355 Train Accuracy: 1.0 Test Accuracy0.933862447739
# Iteration: 1700 Loss: 0.00124133040663 Train Accuracy: 1.0 Test Accuracy0.933862447739
# Iteration: 1800 Loss: 0.00115022191312 Train Accuracy: 1.0 Test Accuracy0.933333337307
# Iteration: 1900 Loss: 0.000993959372863 Train Accuracy: 1.0 Test Accuracy0.935449719429
# Iteration: 2000 Loss: 0.00091305578826 Train Accuracy: 1.0 Test Accuracy0.933862447739
# Iteration: 2100 Loss: 0.000824145332444 Train Accuracy: 1.0 Test Accuracy0.933862447739
# Iteration: 2200 Loss: 0.000774038780946 Train Accuracy: 1.0 Test Accuracy0.932804226875
# Iteration: 2300 Loss: 0.000702660589013 Train Accuracy: 1.0 Test Accuracy0.933862447739
# Iteration: 2400 Loss: 0.000656151387375 Train Accuracy: 1.0 Test Accuracy0.933333337307
# Iteration: 2500 Loss: 0.000614263757598 Train Accuracy: 1.0 Test Accuracy0.931746006012
# Iteration: 2600 Loss: 0.000593486300204 Train Accuracy: 1.0 Test Accuracy0.932804226875
# Iteration: 2700 Loss: 0.000564971764106 Train Accuracy: 1.0 Test Accuracy0.933333337307
# Iteration: 2800 Loss: 0.000529235112481 Train Accuracy: 1.0 Test Accuracy0.931746006012
# Iteration: 2900 Loss: 0.000507329881657 Train Accuracy: 1.0 Test Accuracy0.932275116444
# Iteration: 3000 Loss: 0.000492552877404 Train Accuracy: 1.0 Test Accuracy0.933333337307
# Iteration: 3100 Loss: 0.00047539328807 Train Accuracy: 1.0 Test Accuracy0.933333337307
# Iteration: 3200 Loss: 0.00045786506962 Train Accuracy: 1.0 Test Accuracy0.931746006012
# Iteration: 3300 Loss: 0.000444693752797 Train Accuracy: 1.0 Test Accuracy0.932275116444
# Iteration: 3400 Loss: 0.000434040674008 Train Accuracy: 1.0 Test Accuracy0.931746006012
# Iteration: 3500 Loss: 0.000423948949901 Train Accuracy: 1.0 Test Accuracy0.932275116444
# Iteration: 3600 Loss: 0.000411562738009 Train Accuracy: 1.0 Test Accuracy0.931216955185
# Iteration: 3700 Loss: 0.000404531892855 Train Accuracy: 1.0 Test Accuracy0.932275116444
# Iteration: 3800 Loss: 0.000398491276428 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 3900 Loss: 0.000392070069211 Train Accuracy: 1.0 Test Accuracy0.931746006012
# Iteration: 4000 Loss: 0.000386609870475 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 4100 Loss: 0.000380867772037 Train Accuracy: 1.0 Test Accuracy0.931216955185
# Iteration: 4200 Loss: 0.000375511968741 Train Accuracy: 1.0 Test Accuracy0.931216955185
# Iteration: 4300 Loss: 0.000372537848307 Train Accuracy: 1.0 Test Accuracy0.931216955185
# Iteration: 4400 Loss: 0.000367894303054 Train Accuracy: 1.0 Test Accuracy0.931216955185
# Iteration: 4500 Loss: 0.000365535728633 Train Accuracy: 1.0 Test Accuracy0.931216955185
# Iteration: 4600 Loss: 0.000361560640158 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 4700 Loss: 0.000359817495337 Train Accuracy: 1.0 Test Accuracy0.933333337307
# Iteration: 4800 Loss: 0.00035496574128 Train Accuracy: 1.0 Test Accuracy0.92962962389
# Iteration: 4900 Loss: 0.000352931849193 Train Accuracy: 1.0 Test Accuracy0.931216955185
# Iteration: 5000 Loss: 0.000350865302607 Train Accuracy: 1.0 Test Accuracy0.931746006012
# Iteration: 5100 Loss: 0.000350124028046 Train Accuracy: 1.0 Test Accuracy0.92962962389
# Iteration: 5200 Loss: 0.000348984234734 Train Accuracy: 1.0 Test Accuracy0.92962962389
# Iteration: 5300 Loss: 0.000346579850884 Train Accuracy: 1.0 Test Accuracy0.932275116444
# Iteration: 5400 Loss: 0.00034413850517 Train Accuracy: 1.0 Test Accuracy0.931216955185
# Iteration: 5500 Loss: 0.000342012179317 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 5600 Loss: 0.000340684666298 Train Accuracy: 1.0 Test Accuracy0.931216955185
# Iteration: 5700 Loss: 0.000338805519277 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 5800 Loss: 0.00033798100776 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 5900 Loss: 0.000336440309184 Train Accuracy: 1.0 Test Accuracy0.930158734322
# Iteration: 6000 Loss: 0.000334857817506 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 6100 Loss: 0.000334327109158 Train Accuracy: 1.0 Test Accuracy0.930158734322
# Iteration: 6200 Loss: 0.000332742580213 Train Accuracy: 1.0 Test Accuracy0.931216955185
# Iteration: 6300 Loss: 0.000331647897838 Train Accuracy: 1.0 Test Accuracy0.92962962389
# Iteration: 6400 Loss: 0.000329458533088 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 6500 Loss: 0.000328503199853 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 6600 Loss: 0.000327509536874 Train Accuracy: 1.0 Test Accuracy0.928571403027
# Iteration: 6700 Loss: 0.000326700042933 Train Accuracy: 1.0 Test Accuracy0.932275116444
# Iteration: 6800 Loss: 0.000326643203152 Train Accuracy: 1.0 Test Accuracy0.92962962389
# Iteration: 6900 Loss: 0.00032412094879 Train Accuracy: 1.0 Test Accuracy0.930158734322
# Iteration: 7000 Loss: 0.0003225262044 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 7100 Loss: 0.000322640495142 Train Accuracy: 1.0 Test Accuracy0.931746006012
# Iteration: 7200 Loss: 0.000320916471537 Train Accuracy: 1.0 Test Accuracy0.931746006012
# Iteration: 7300 Loss: 0.000319640617818 Train Accuracy: 1.0 Test Accuracy0.930158734322
# Iteration: 7400 Loss: 0.000317914498737 Train Accuracy: 1.0 Test Accuracy0.930158734322
# Iteration: 7500 Loss: 0.000316259975079 Train Accuracy: 1.0 Test Accuracy0.932804226875
# Iteration: 7600 Loss: 0.000316248624586 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 7700 Loss: 0.000312379037496 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 7800 Loss: 0.000312459887937 Train Accuracy: 1.0 Test Accuracy0.92962962389
# Iteration: 7900 Loss: 0.000310416042339 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 8000 Loss: 0.000309498078423 Train Accuracy: 1.0 Test Accuracy0.930158734322
# Iteration: 8100 Loss: 0.000306768051814 Train Accuracy: 1.0 Test Accuracy0.930158734322
# Iteration: 8200 Loss: 0.000304663815768 Train Accuracy: 1.0 Test Accuracy0.929100513458
# Iteration: 8300 Loss: 0.000303831591737 Train Accuracy: 1.0 Test Accuracy0.928571403027
# Iteration: 8400 Loss: 0.000301458523609 Train Accuracy: 1.0 Test Accuracy0.929100513458
# Iteration: 8500 Loss: 0.000299533392536 Train Accuracy: 1.0 Test Accuracy0.92962962389
# Iteration: 8600 Loss: 0.000299090723274 Train Accuracy: 1.0 Test Accuracy0.929100513458
# Iteration: 8700 Loss: 0.000299990439089 Train Accuracy: 1.0 Test Accuracy0.930158734322
# Iteration: 8800 Loss: 0.000300132262055 Train Accuracy: 1.0 Test Accuracy0.9280423522
# Iteration: 8900 Loss: 0.000294511119137 Train Accuracy: 1.0 Test Accuracy0.931216955185
# Iteration: 9000 Loss: 0.000291656848276 Train Accuracy: 1.0 Test Accuracy0.92962962389
# Iteration: 9100 Loss: 0.000291396019747 Train Accuracy: 1.0 Test Accuracy0.928571403027
# Iteration: 9200 Loss: 0.000289071060251 Train Accuracy: 1.0 Test Accuracy0.931746006012
# Iteration: 9300 Loss: 0.000287820352241 Train Accuracy: 1.0 Test Accuracy0.931216955185
# Iteration: 9400 Loss: 0.000285219255602 Train Accuracy: 1.0 Test Accuracy0.931746006012
# Iteration: 9500 Loss: 0.00028513680445 Train Accuracy: 1.0 Test Accuracy0.930687844753
# Iteration: 9600 Loss: 0.000289282150334 Train Accuracy: 1.0 Test Accuracy0.933333337307
# Iteration: 9700 Loss: 0.000902134808712 Train Accuracy: 1.0 Test Accuracy0.937566161156
# Iteration: 9800 Loss: 0.000519757857546 Train Accuracy: 1.0 Test Accuracy0.940211653709
# Iteration: 9900 Loss: 0.000469587102998 Train Accuracy: 1.0 Test Accuracy0.941269814968
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: model/saved_model.pb
