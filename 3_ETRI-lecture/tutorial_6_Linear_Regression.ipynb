# %%
# X 와 Y 의 상관관계를 분석하는 기초적인 선형 회귀 모델을 만들고 실행해봅니다.
import tensorflow as tf

x_data = [1, 2, 3]
y_data = [1, 2, 3]

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

# name: 나중에 텐서보드등으로 값의 변화를 추적하거나 살펴보기 쉽게 하기 위해 이름을 붙여줍니다.
X = tf.placeholder(tf.float32, name="X")
Y = tf.placeholder(tf.float32, name="Y")
print(X)
print(Y)

# X 와 Y 의 상관 관계를 분석하기 위한 가설 수식을 작성합니다.
# y = W * x + b
# W 와 X 가 행렬이 아니므로 tf.matmul 이 아니라 기본 곱셈 기호를 사용했습니다.
hypothesis = W * X + b

# 손실 함수를 작성합니다.
# mean(h - Y)^2 : 예측값과 실제값의 거리를 비용(손실) 함수로 정합니다.
cost = tf.reduce_mean(tf.square(hypothesis - Y))
# 텐서플로우에 기본적으로 포함되어 있는 함수를 이용해 경사 하강법 최적화를 수행합니다.
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
# 비용을 최소화 하는 것이 최종 목표
train_op = optimizer.minimize(cost)

# 세션을 생성하고 초기화합니다.
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    # 최적화를 100번 수행합니다.
    for step in range(100):
        # sess.run 을 통해 train_op 와 cost 그래프를 계산합니다.
        # 이 때, 가설 수식에 넣어야 할 실제값을 feed_dict 을 통해 전달합니다.
        _, cost_val = sess.run([train_op, cost], feed_dict={X: x_data, Y: y_data})

        print(step, cost_val, sess.run(W), sess.run(b))

    # 최적화가 완료된 모델에 테스트 값을 넣고 결과가 잘 나오는지 확인해봅니다.
    print("\n=== Test ===")
    print("X: 5, Y:", sess.run(hypothesis, feed_dict={X: 5}))
    print("X: 2.5, Y:", sess.run(hypothesis, feed_dict={X: 2.5}))
# Out:
# Tensor("X:0", dtype=float32)
# Tensor("Y:0", dtype=float32)
# (0, 12.635768, array([ 0.69080031], dtype=float32), array([ 1.10989642], dtype=float32))
# (1, 0.30530566, array([ 0.53542811], dtype=float32), array([ 1.01159704], dtype=float32))
# (2, 0.15068327, array([ 0.56438971], dtype=float32), array([ 0.9951064], dtype=float32))
# (3, 0.14185193, array([ 0.57291675], dtype=float32), array([ 0.97032923], dtype=float32))
# (4, 0.13509385, array([ 0.58339608], dtype=float32), array([ 0.94709665], dtype=float32))
# (5, 0.12867655, array([ 0.59338772], dtype=float32), array([ 0.92431891], dtype=float32))
# (6, 0.12256432, array([ 0.60316491], dtype=float32), array([ 0.90210003], dtype=float32))
# (7, 0.11674243, array([ 0.61270428], dtype=float32), array([ 0.88041407], dtype=float32))
# (8, 0.11119706, array([ 0.6220147], dtype=float32), array([ 0.85924953], dtype=float32))
# (9, 0.10591512, array([ 0.63110119], dtype=float32), array([ 0.83859372], dtype=float32))
# (10, 0.10088406, array([ 0.63996923], dtype=float32), array([ 0.81843448], dtype=float32))
# (11, 0.096091986, array([ 0.64862412], dtype=float32), array([ 0.79875988], dtype=float32))
# (12, 0.091527559, array([ 0.65707099], dtype=float32), array([ 0.77955824], dtype=float32))
# (13, 0.087179936, array([ 0.66531473], dtype=float32), array([ 0.76081818], dtype=float32))
# (14, 0.083038799, array([ 0.67336035], dtype=float32), array([ 0.74252868], dtype=float32))
# (15, 0.079094425, array([ 0.68121254], dtype=float32), array([ 0.72467881], dtype=float32))
# (16, 0.075337388, array([ 0.68887597], dtype=float32), array([ 0.70725805], dtype=float32))
# (17, 0.071758807, array([ 0.69635516], dtype=float32), array([ 0.69025606], dtype=float32))
# (18, 0.068350196, array([ 0.70365459], dtype=float32), array([ 0.67366278], dtype=float32))
# (19, 0.065103546, array([ 0.71077853], dtype=float32), array([ 0.65746838], dtype=float32))
# (20, 0.062011063, array([ 0.71773124], dtype=float32), array([ 0.64166331], dtype=float32))
# (21, 0.059065487, array([ 0.72451675], dtype=float32), array([ 0.62623817], dtype=float32))
# (22, 0.056259871, array([ 0.73113924], dtype=float32), array([ 0.61118382], dtype=float32))
# (23, 0.053587426, array([ 0.73760241], dtype=float32), array([ 0.59649134], dtype=float32))
# (24, 0.051042031, array([ 0.74391031], dtype=float32), array([ 0.58215207], dtype=float32))
# (25, 0.048617471, array([ 0.75006652], dtype=float32), array([ 0.56815749], dtype=float32))
# (26, 0.046308085, array([ 0.75607479], dtype=float32), array([ 0.55449939], dtype=float32))
# (27, 0.044108439, array([ 0.76193857], dtype=float32), array([ 0.54116958], dtype=float32))
# (28, 0.042013247, array([ 0.76766139], dtype=float32), array([ 0.52816021], dtype=float32))
# (29, 0.040017594, array([ 0.77324671], dtype=float32), array([ 0.51546359], dtype=float32))
# (30, 0.03811672, array([ 0.77869773], dtype=float32), array([ 0.5030722], dtype=float32))
# (31, 0.036306139, array([ 0.78401762], dtype=float32), array([ 0.49097866], dtype=float32))
# (32, 0.034581549, array([ 0.78920972], dtype=float32), array([ 0.47917587], dtype=float32))
# (33, 0.032938942, array([ 0.79427701], dtype=float32), array([ 0.46765682], dtype=float32))
# (34, 0.031374276, array([ 0.79922241], dtype=float32), array([ 0.45641464], dtype=float32))
# (35, 0.029883986, array([ 0.80404896], dtype=float32), array([ 0.44544277], dtype=float32))
# (36, 0.028464489, array([ 0.80875951], dtype=float32), array([ 0.43473464], dtype=float32))
# (37, 0.027112396, array([ 0.81335676], dtype=float32), array([ 0.42428389], dtype=float32))
# (38, 0.025824538, array([ 0.81784356], dtype=float32), array([ 0.4140844], dtype=float32))
# (39, 0.024597844, array([ 0.82222241], dtype=float32), array([ 0.4041301], dtype=float32))
# (40, 0.023429444, array([ 0.82649618], dtype=float32), array([ 0.39441514], dtype=float32))
# (41, 0.02231651, array([ 0.83066702], dtype=float32), array([ 0.38493362], dtype=float32))
# (42, 0.02125646, array([ 0.83473766], dtype=float32), array([ 0.37568009], dtype=float32))
# (43, 0.020246794, array([ 0.83871049], dtype=float32), array([ 0.366649], dtype=float32))
# (44, 0.019285042, array([ 0.84258777], dtype=float32), array([ 0.35783502], dtype=float32))
# (45, 0.018368969, array([ 0.84637183], dtype=float32), array([ 0.34923291], dtype=float32))
# (46, 0.01749645, array([ 0.85006499], dtype=float32), array([ 0.3408376], dtype=float32))
# (47, 0.016665334, array([ 0.85366929], dtype=float32), array([ 0.33264408], dtype=float32))
# (48, 0.01587373, array([ 0.85718697], dtype=float32), array([ 0.32464755], dtype=float32))
# (49, 0.015119721, array([ 0.86062014], dtype=float32), array([ 0.31684327], dtype=float32))
# (50, 0.014401511, array([ 0.8639707], dtype=float32), array([ 0.30922654], dtype=float32))
# (51, 0.013717447, array([ 0.86724079], dtype=float32), array([ 0.30179295], dtype=float32))
# (52, 0.013065861, array([ 0.87043226], dtype=float32), array([ 0.29453805], dtype=float32))
# (53, 0.012445214, array([ 0.87354696], dtype=float32), array([ 0.28745756], dtype=float32))
# (54, 0.011854065, array([ 0.87658685], dtype=float32), array([ 0.28054729], dtype=float32))
# (55, 0.011290976, array([ 0.87955356], dtype=float32), array([ 0.27380309], dtype=float32))
# (56, 0.010754651, array([ 0.88244903], dtype=float32), array([ 0.26722106], dtype=float32))
# (57, 0.010243804, array([ 0.88527489], dtype=float32), array([ 0.26079726], dtype=float32))
# (58, 0.0097572049, array([ 0.88803273], dtype=float32), array([ 0.25452787], dtype=float32))
# (59, 0.0092937322, array([ 0.89072436], dtype=float32), array([ 0.2484092], dtype=float32))
# (60, 0.0088522714, array([ 0.89335126], dtype=float32), array([ 0.24243762], dtype=float32))
# (61, 0.0084317932, array([ 0.89591503], dtype=float32), array([ 0.23660958], dtype=float32))
# (62, 0.0080312705, array([ 0.89841723], dtype=float32), array([ 0.23092167], dtype=float32))
# (63, 0.0076497695, array([ 0.90085912], dtype=float32), array([ 0.22537044], dtype=float32))
# (64, 0.0072864047, array([ 0.90324247], dtype=float32), array([ 0.2199527], dtype=float32))
# (65, 0.006940309, array([ 0.90556842], dtype=float32), array([ 0.21466517], dtype=float32))
# (66, 0.0066106208, array([ 0.90783846], dtype=float32), array([ 0.20950477], dtype=float32))
# (67, 0.0062966063, array([ 0.91005397], dtype=float32), array([ 0.20446841], dtype=float32))
# (68, 0.0059975176, array([ 0.91221619], dtype=float32), array([ 0.19955313], dtype=float32))
# (69, 0.0057126395, array([ 0.91432655], dtype=float32), array([ 0.19475605], dtype=float32))
# (70, 0.0054412857, array([ 0.91638607], dtype=float32), array([ 0.19007424], dtype=float32))
# (71, 0.0051828236, array([ 0.91839606], dtype=float32), array([ 0.18550496], dtype=float32))
# (72, 0.0049366299, array([ 0.92035776], dtype=float32), array([ 0.18104553], dtype=float32))
# (73, 0.0047021261, array([ 0.92227232], dtype=float32), array([ 0.17669334], dtype=float32))
# (74, 0.0044787717, array([ 0.92414075], dtype=float32), array([ 0.17244571], dtype=float32))
# (75, 0.0042660297, array([ 0.92596442], dtype=float32), array([ 0.16830027], dtype=float32))
# (76, 0.0040633925, array([ 0.92774415], dtype=float32), array([ 0.16425444], dtype=float32))
# (77, 0.0038703803, array([ 0.92948115], dtype=float32), array([ 0.1603059], dtype=float32))
# (78, 0.0036865275, array([ 0.93117636], dtype=float32), array([ 0.15645225], dtype=float32))
# (79, 0.0035114267, array([ 0.93283087], dtype=float32), array([ 0.15269126], dtype=float32))
# (80, 0.0033446243, array([ 0.9344455], dtype=float32), array([ 0.14902064], dtype=float32))
# (81, 0.0031857525, array([ 0.93602139], dtype=float32), array([ 0.1454383], dtype=float32))
# (82, 0.0030344289, array([ 0.93755943], dtype=float32), array([ 0.14194208], dtype=float32))
# (83, 0.0028902933, array([ 0.93906045], dtype=float32), array([ 0.1385299], dtype=float32))
# (84, 0.0027529967, array([ 0.94052541], dtype=float32), array([ 0.13519974], dtype=float32))
# (85, 0.0026222367, array([ 0.94195515], dtype=float32), array([ 0.13194963], dtype=float32))
# (86, 0.0024976691, array([ 0.94335049], dtype=float32), array([ 0.12877765], dtype=float32))
# (87, 0.002379033, array([ 0.94471228], dtype=float32), array([ 0.12568192], dtype=float32))
# (88, 0.0022660224, array([ 0.94604141], dtype=float32), array([ 0.12266062], dtype=float32))
# (89, 0.0021583836, array([ 0.94733852], dtype=float32), array([ 0.11971194], dtype=float32))
# (90, 0.0020558673, array([ 0.94860446], dtype=float32), array([ 0.11683415], dtype=float32))
# (91, 0.0019582121, array([ 0.94984001], dtype=float32), array([ 0.11402554], dtype=float32))
# (92, 0.0018651913, array([ 0.95104581], dtype=float32), array([ 0.11128443], dtype=float32))
# (93, 0.0017765906, array([ 0.95222259], dtype=float32), array([ 0.10860922], dtype=float32))
# (94, 0.0016922042, array([ 0.95337117], dtype=float32), array([ 0.10599834], dtype=float32))
# (95, 0.0016118238, array([ 0.95449209], dtype=float32), array([ 0.10345021], dtype=float32))
# (96, 0.0015352583, array([ 0.95558602], dtype=float32), array([ 0.10096332], dtype=float32))
# (97, 0.001462331, array([ 0.95665371], dtype=float32), array([ 0.09853625], dtype=float32))
# (98, 0.0013928706, array([ 0.95769572], dtype=float32), array([ 0.0961675], dtype=float32))
# (99, 0.0013267078, array([ 0.9587127], dtype=float32), array([ 0.0938557], dtype=float32))
#
# === Test ===
# ('X: 5, Y:', array([ 4.88741922], dtype=float32))
# ('X: 2.5, Y:', array([ 2.4906373], dtype=float32))
